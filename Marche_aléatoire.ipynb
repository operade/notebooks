# %% [markdown]
# <a href="https://colab.research.google.com/github/operade/notebooks/blob/master/Marche_al%C3%A9atoire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# marche aleatoire dans $\mathbb Z^2$

# %%
from numpy.random import choice
Liste = [[0,1],[0,-1],[1,0],[-1,0]]
def marche(n):
  indices = [0,1,2,3]
  S = [0,0]
  L = [S]
  for i in range(n):
    i = choice(indices)
    a = S[0]+Liste[i][0]
    b = S[1]+Liste[i][1]
    S = [a,b]
    L.append(S)
  return L

# %%
print(marche(100))
# Out:
# [[0, 0], [0, 1], [0, 2], [0, 1], [-1, 1], [-2, 1], [-1, 1], [-1, 0], [-1, 1], [-2, 1], [-2, 2], [-2, 1], [-2, 2], [-2, 1], [-2, 0], [-3, 0], [-4, 0], [-4, 1], [-4, 0], [-4, -1], [-4, 0], [-5, 0], [-4, 0], [-3, 0], [-2, 0], [-2, -1], [-2, -2], [-2, -3], [-1, -3], [-2, -3], [-2, -4], [-1, -4], [0, -4], [0, -5], [0, -4], [1, -4], [0, -4], [0, -5], [-1, -5], [-1, -6], [-2, -6], [-1, -6], [0, -6], [0, -5], [1, -5], [2, -5], [1, -5], [0, -5], [1, -5], [1, -6], [2, -6], [2, -7], [3, -7], [3, -6], [3, -5], [4, -5], [4, -6], [4, -5], [4, -4], [4, -5], [3, -5], [4, -5], [4, -6], [4, -7], [4, -6], [4, -7], [4, -6], [5, -6], [4, -6], [4, -5], [4, -4], [3, -4], [3, -3], [3, -4], [3, -3], [3, -4], [4, -4], [4, -3], [4, -2], [5, -2], [6, -2], [5, -2], [4, -2], [4, -1], [4, -2], [4, -3], [3, -3], [4, -3], [5, -3], [5, -2], [4, -2], [4, -1], [4, -2], [4, -1], [3, -1], [3, 0], [3, -1], [3, -2], [4, -2], [4, -1], [3, -1]]

# %%
import matplotlib.pyplot as plt
L = marche(10000)
x = [L[i][0] for i in range(len(L))]
y = [L[i][1] for i in range(len(L))]
plt.plot(x,y)
plt.show()
